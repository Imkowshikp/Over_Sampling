# %% [markdown]
# ## Kowshik
# ## Orden - Over Sampling
# ## Accuracy - 0.99

# %%
import pandas as pd;
import numpy as np;
from matplotlib import pyplot as plt;
import seaborn as sns;

# %%
rawData = pd.read_csv("finalOutput_orden.csv")

rawData
# Out:
#       S.No          BP         AT        PM10         RH       PM2.5  \
# 0        1  739.927841  29.592495  444.669402  50.346059  155.981714
# 1        2  739.927841  29.592495  444.669402  50.346059  155.981714
# 2        3  739.927841  29.592495  444.669402  50.346059  155.981714
# 3        4  739.927841  29.592495  444.669402  50.346059  155.981714
# 4        5  739.927841  29.592495  444.669402  50.346059  155.981714
# ...    ...         ...        ...         ...        ...         ...
# 2491  2492  972.180417  34.841250  112.833333  68.402083   41.104167
# 2492  2493  972.026250  36.314167  288.927083  59.525833   75.822917
# 2493  2494  971.963750  32.397500   83.135417  84.377083   44.541667
# 2494  2495  972.887083  34.719167  312.250000  55.533750   75.531250
# 2495  2496  973.959583  24.862500  716.533963  72.664167  264.003210
#
#               WD        WS        NH3        CO          NO         NO2  \
# 0     182.398863  1.685305  49.899503  1.667151   94.785703   76.884928
# 1     182.398863  1.685305  49.899503  1.667151   94.785703   76.884928
# 2     182.398863  1.685305  49.899503  1.667151   94.785703   76.884928
# 3     182.398863  1.685305  49.899503  1.667151   94.785703   76.884928
# 4     182.398863  1.685305  49.899503  1.667151   94.785703   76.884928
# ...          ...       ...        ...       ...         ...         ...
# 2491   91.885417  2.437917  40.789167  1.719583    7.340833   26.114167
# 2492  237.239583  0.865833  29.330000  2.177561   96.387500   44.670833
# 2493  131.479167  0.590000  39.906704  2.177561   86.847517   71.109110
# 2494  248.406250  0.470417  34.950417  2.177561  166.466563   86.191250
# 2495  228.958333  0.300000  52.736534  2.177561  225.919276  158.741667
#
#              NOx        SO2      Ozone  AQI Simulink      Label
# 0     229.145198  23.380207  29.654703       6.285714  Moderate
# 1     229.145198  23.380207  29.654703       6.285714  Moderate
# 2     229.145198  23.380207  29.654703       6.285714  Moderate
# 3     229.145198  23.380207  29.654703       6.285714  Moderate
# 4     229.145198  23.380207  29.654703       6.285714  Moderate
# ...          ...        ...        ...            ...       ...
# 2491   19.872500   6.555000  21.977046       4.575486  Moderate
# 2492  102.346250   8.974583   7.061667       5.285714  Moderate
# 2493  111.700845  10.585417  12.381667       5.285714  Moderate
# 2494  187.012119  21.204167  30.482500       5.699442  Moderate
# 2495  274.951461  18.738416   5.662917       4.137296   Healthy
#
# [2496 rows x 17 columns]

# %%
rawData.drop(rawData.columns[[0, 15]], axis = 1, inplace = True);

clientDataAltered = rawData;

clientDataAltered
# Out:
#               BP         AT        PM10         RH       PM2.5          WD  \
# 0     739.927841  29.592495  444.669402  50.346059  155.981714  182.398863
# 1     739.927841  29.592495  444.669402  50.346059  155.981714  182.398863
# 2     739.927841  29.592495  444.669402  50.346059  155.981714  182.398863
# 3     739.927841  29.592495  444.669402  50.346059  155.981714  182.398863
# 4     739.927841  29.592495  444.669402  50.346059  155.981714  182.398863
# ...          ...        ...         ...        ...         ...         ...
# 2491  972.180417  34.841250  112.833333  68.402083   41.104167   91.885417
# 2492  972.026250  36.314167  288.927083  59.525833   75.822917  237.239583
# 2493  971.963750  32.397500   83.135417  84.377083   44.541667  131.479167
# 2494  972.887083  34.719167  312.250000  55.533750   75.531250  248.406250
# 2495  973.959583  24.862500  716.533963  72.664167  264.003210  228.958333
#
#             WS        NH3        CO          NO         NO2         NOx  \
# 0     1.685305  49.899503  1.667151   94.785703   76.884928  229.145198
# 1     1.685305  49.899503  1.667151   94.785703   76.884928  229.145198
# 2     1.685305  49.899503  1.667151   94.785703   76.884928  229.145198
# 3     1.685305  49.899503  1.667151   94.785703   76.884928  229.145198
# 4     1.685305  49.899503  1.667151   94.785703   76.884928  229.145198
# ...        ...        ...       ...         ...         ...         ...
# 2491  2.437917  40.789167  1.719583    7.340833   26.114167   19.872500
# 2492  0.865833  29.330000  2.177561   96.387500   44.670833  102.346250
# 2493  0.590000  39.906704  2.177561   86.847517   71.109110  111.700845
# 2494  0.470417  34.950417  2.177561  166.466563   86.191250  187.012119
# 2495  0.300000  52.736534  2.177561  225.919276  158.741667  274.951461
#
#             SO2      Ozone     Label
# 0     23.380207  29.654703  Moderate
# 1     23.380207  29.654703  Moderate
# 2     23.380207  29.654703  Moderate
# 3     23.380207  29.654703  Moderate
# 4     23.380207  29.654703  Moderate
# ...         ...        ...       ...
# 2491   6.555000  21.977046  Moderate
# 2492   8.974583   7.061667  Moderate
# 2493  10.585417  12.381667  Moderate
# 2494  21.204167  30.482500  Moderate
# 2495  18.738416   5.662917   Healthy
#
# [2496 rows x 15 columns]

# %%
columns = clientDataAltered.columns.tolist()

columns = [c for c in columns if c not in ["Label"]]

target = "Label"

state = np.random.RandomState(42)

x = clientDataAltered[columns]

y = clientDataAltered[target]

# %%
x
# Out:
#               BP         AT        PM10         RH       PM2.5          WD  \
# 0     739.927841  29.592495  444.669402  50.346059  155.981714  182.398863
# 1     739.927841  29.592495  444.669402  50.346059  155.981714  182.398863
# 2     739.927841  29.592495  444.669402  50.346059  155.981714  182.398863
# 3     739.927841  29.592495  444.669402  50.346059  155.981714  182.398863
# 4     739.927841  29.592495  444.669402  50.346059  155.981714  182.398863
# ...          ...        ...         ...        ...         ...         ...
# 2491  972.180417  34.841250  112.833333  68.402083   41.104167   91.885417
# 2492  972.026250  36.314167  288.927083  59.525833   75.822917  237.239583
# 2493  971.963750  32.397500   83.135417  84.377083   44.541667  131.479167
# 2494  972.887083  34.719167  312.250000  55.533750   75.531250  248.406250
# 2495  973.959583  24.862500  716.533963  72.664167  264.003210  228.958333
#
#             WS        NH3        CO          NO         NO2         NOx  \
# 0     1.685305  49.899503  1.667151   94.785703   76.884928  229.145198
# 1     1.685305  49.899503  1.667151   94.785703   76.884928  229.145198
# 2     1.685305  49.899503  1.667151   94.785703   76.884928  229.145198
# 3     1.685305  49.899503  1.667151   94.785703   76.884928  229.145198
# 4     1.685305  49.899503  1.667151   94.785703   76.884928  229.145198
# ...        ...        ...       ...         ...         ...         ...
# 2491  2.437917  40.789167  1.719583    7.340833   26.114167   19.872500
# 2492  0.865833  29.330000  2.177561   96.387500   44.670833  102.346250
# 2493  0.590000  39.906704  2.177561   86.847517   71.109110  111.700845
# 2494  0.470417  34.950417  2.177561  166.466563   86.191250  187.012119
# 2495  0.300000  52.736534  2.177561  225.919276  158.741667  274.951461
#
#             SO2      Ozone
# 0     23.380207  29.654703
# 1     23.380207  29.654703
# 2     23.380207  29.654703
# 3     23.380207  29.654703
# 4     23.380207  29.654703
# ...         ...        ...
# 2491   6.555000  21.977046
# 2492   8.974583   7.061667
# 2493  10.585417  12.381667
# 2494  21.204167  30.482500
# 2495  18.738416   5.662917
#
# [2496 rows x 14 columns]

# %%
y
# Out:
# 0       Moderate
# 1       Moderate
# 2       Moderate
# 3       Moderate
# 4       Moderate
#           ...
# 2491    Moderate
# 2492    Moderate
# 2493    Moderate
# 2494    Moderate
# 2495     Healthy
# Name: Label, Length: 2496, dtype: object

# %%
countClass_moderate, countClass_Healthy, countClass_Unhealthy = clientDataAltered.Label.value_counts()

# %%
countClass_moderate, countClass_Healthy, countClass_Unhealthy
# Out:
# (2138, 253, 105)

# %%
x.shape, y.shape
# Out:
# ((2496, 14), (2496,))

# %%
Moderate = clientDataAltered[clientDataAltered["Label"] == "Moderate"]

Healthy = clientDataAltered[clientDataAltered["Label"] == "Healthy"]

Unhealthy = clientDataAltered[clientDataAltered["Label"] == "Unhealthy"]

# %%
Moderate.shape, Healthy.shape, Unhealthy.shape
# Out:
# ((2138, 15), (105, 15), (253, 15))

# %%
from imblearn.over_sampling import SMOTE

overSample = SMOTE(random_state = 42)

x_res, y_res = overSample.fit_resample(x, y)

# %%
x_res.shape, y_res.shape
# Out:
# ((6414, 14), (6414,))

# %%
from collections import Counter

print("Original dataset shape {}".format(Counter(y)))

print("Resampled dataset shape {}".format(Counter(y_res)))
# Out:
# Original dataset shape Counter({'Moderate': 2138, 'Unhealthy': 253, 'Healthy': 105})
# Resampled dataset shape Counter({'Moderate': 2138, 'Healthy': 2138, 'Unhealthy': 2138})

# %%
from imblearn.over_sampling import RandomOverSampler

os = RandomOverSampler(random_state = 42, sampling_strategy='auto', shrinkage=None)


x_train_res, y_train_res = os.fit_resample(x, y)

# %%
x_train_res.shape, y_train_res.shape
# Out:
# ((6414, 14), (6414,))

# %%
from collections import Counter

print("Original dataset shape {}".format(Counter(y)))

print("Resampled dataset shape {}".format(Counter(y_train_res)))
# Out:
# Original dataset shape Counter({'Moderate': 2138, 'Unhealthy': 253, 'Healthy': 105})
# Resampled dataset shape Counter({'Moderate': 2138, 'Healthy': 2138, 'Unhealthy': 2138})

# %%
from sklearn.model_selection import train_test_split;

x_train, x_test, y_train, y_test = train_test_split(x_train_res, y_train_res, test_size = 1/3, random_state = 6, stratify = y_train_res);

# %%
from imblearn.over_sampling import RandomOverSampler

os = RandomOverSampler(random_state = 42, sampling_strategy='auto', shrinkage=None)


x_test_res, y_test_res = os.fit_resample(x_test, y_test)

# %%
from collections import Counter

print("Original dataset shape {}".format(Counter(y)))

print("Resampled dataset shape {}".format(Counter(y_test_res)))
# Out:
# Original dataset shape Counter({'Moderate': 2138, 'Unhealthy': 253, 'Healthy': 105})
# Resampled dataset shape Counter({'Healthy': 713, 'Moderate': 713, 'Unhealthy': 713})

# %%
#from sklearn.model_selection import train_test_split;

#x_train_1, x_test_1, y_train_2, y_test_2 = train_test_split(x_test_res, y_test_res, test_size = 1/3, random_state = 6, stratify = y_train_res);

# %%
#x_test_res.shape, y_test_res.shape

# %%
from sklearn.preprocessing import StandardScaler;

standardization = StandardScaler();

x_train = standardization.fit_transform(x_train);

x_test = standardization.transform(x_test);

# %%
from sklearn.svm import SVC;

from sklearn.model_selection import GridSearchCV;



param_grid ={"kernel":["Linear", "poly", "rbf"], "C":[1.0, 10, 20, 50, 80, 100], 
             
             "degree":[1, 2, 3], "gamma":["auto", "scale"]
             
    
            }

grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3, n_jobs=-1, scoring="f1_weighted");

grid.fit(x_train, y_train);
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 180 fits failed out of a total of 540.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\sklearn\svm\_base.py", line 255, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\sklearn\svm\_base.py", line 333, in _dense_fit
#     random_seed=random_seed,
#   File "sklearn\svm\_libsvm.pyx", line 173, in sklearn.svm._libsvm.fit
# ValueError: 'Linear' is not in list
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\sklearn\model_selection\_search.py:972: UserWarning: One or more of the test scores are non-finite: [       nan 0.80323613 0.95720673        nan 0.80323613 0.95720673
#         nan 0.89053411 0.95720673        nan 0.89053411 0.95720673
#         nan 0.93469668 0.95720673        nan 0.93469668 0.95720673
#         nan 0.80264588 0.97975072        nan 0.80378347 0.97975072
#         nan 0.92126572 0.97975072        nan 0.92150799 0.97975072
#         nan 0.95084586 0.97975072        nan 0.95084586 0.97975072
#         nan 0.80171161 0.98235976        nan 0.80149492 0.98235976
#         nan 0.92753315 0.98235976        nan 0.9272894  0.98235976
#         nan 0.95693416 0.98235976        nan 0.95693416 0.98235976
#         nan 0.80290457 0.98447647        nan 0.80242867 0.98447647
#         nan 0.93493772 0.98447647        nan 0.93493772 0.98447647
#         nan 0.96655918 0.98447647        nan 0.96632248 0.98447647
#         nan 0.80427812 0.98542205        nan 0.80427812 0.98542205
#         nan 0.9392722  0.98542205        nan 0.9392722  0.98542205
#         nan 0.96578884 0.98542205        nan 0.96578884 0.98542205
#         nan 0.80404925 0.98589539        nan 0.80426431 0.98589539
#         nan 0.93896092 0.98589539        nan 0.9387217  0.98589539
#         nan 0.96527422 0.98589539        nan 0.96551736 0.98589539]
#   category=UserWarning,

# %%
y_pred = grid.predict(x_test);

# %%
from sklearn.metrics import confusion_matrix;

logisticRegressionConfusionMatrix = confusion_matrix(y_test, y_pred);

print(logisticRegressionConfusionMatrix);
# Out:
# [[712   0   0]
#  [ 16 684  13]
#  [  0   0 713]]

# %%
from sklearn.metrics import classification_report;

logisticRegressionClassifierReport = classification_report(y_test, y_pred);

print(logisticRegressionClassifierReport);
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.98      1.00      0.99       712
#     Moderate       1.00      0.96      0.98       713
#    Unhealthy       0.98      1.00      0.99       713
#
#     accuracy                           0.99      2138
#    macro avg       0.99      0.99      0.99      2138
# weighted avg       0.99      0.99      0.99      2138

# %%
from sklearn.metrics import accuracy_score;

SVMClassifierAccuracy = accuracy_score(y_test, y_pred);

print(SVMClassifierAccuracy);
# Out:
# 0.9864359214218896

# %%
from sklearn.metrics import balanced_accuracy_score;

SVMClassifierBalanced = balanced_accuracy_score(y_test, y_pred);

print(SVMClassifierBalanced);
# Out:
# 0.9864422627395979
